# %% [markdown]
# # **Introduction**

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.load('multidim_data_trainval.npy', allow_pickle = True).item()

# %%
list(data)

Y_train = list(data.values())[0]
X_train = list(data.values())[1]
Y_test = list(data.values())[2]
X_test = list(data.values())[3]

# %% [markdown]
# # **Part b)**

# %% [markdown]
# *1)*

# %%
#provided_functions.py

def Lasso(Phi, Y, lmbd):
    ''' compute weight of linear regression with Lasso

    Phi: design matrix n x d
    Y: true values n x 1
    lmbd: weight of regularization

    output: weights of linear regression d x 1
    '''

    # initialize wplus, wminus
    wplus = np.random.rand(Phi.shape[1], 1) # generate Phi.shape[1] random numbers
    wminus = np.random.rand(*wplus.shape) # generate same number of random numbers as for wplus

    loss = LassoObjective(wplus, wminus, Phi, Y, lmbd)

    counter = 1
    while counter > 0:
        # compute gradients wrt wplus and wminus
        gradwplus, gradwminus = GradLassoObjective(wplus, wminus, Phi, Y, lmbd)

        # compute new iterates
        wplus, wminus, loss = getStepSize(wplus, wminus, Phi, Y, lmbd, gradwplus, gradwminus, loss)

        if (counter % 100) == 0: # only generate output each 100 iterations
            # check if stopping criterion is met
            wnew = wplus - wminus
            ind = wnew != 0. # indicates nonzero weights
            indz = wnew == 0.
            r = 2 / Phi.shape[0] * (Phi.T @ (Phi @ wnew - Y))
            stop = np.abs(r[ind] + lmbd * np.sign(wnew[ind])).sum() + (np.abs(r[indz]) - lmbd * np.ones_like(
                r[indz])).clip(0.).sum()
            print('iter={} current objective={:.3f} nonzero weights={}'.format(
                counter, loss, ind.sum()) +\
                ' stop={:.5f}'.format(stop / Phi.shape[0]))
            if np.abs(stop) / Phi.shape[0] < 1e-5: # stopping criterion
                break
        counter += 1


    return wplus - wminus


############################################################


def LassoObjective(wplus, wminus, Phi, Y, lmbd):
    ''' evaluates the objective function at (wplus, wminus)
    L2 loss + L1 regularization
    '''
    w = wplus - wminus
    return ((Phi @ w - Y) ** 2).mean() + lmbd * np.abs(w).sum()



def GradLassoObjective(wplus, wminus, Phi, Y, lmbd):
    ''' computes the gradients of the objective function
    at (wplus, wminus)
    gradwplus: gradient wrt wplus
    gradwminus: gradient wrt minus

    for the derivation of the respective gradient, please refer to the pdf (part b.1)
    '''
 
    gradwplus = (2/Phi.shape[0]) * Phi.T @ (- Y + Phi @ wplus - Phi @ wminus) + np.ones((Phi.shape[1], 1)) * lmbd
    gradwminus = (2/Phi.shape[0]) * Phi.T @ (Y - Phi @ wplus + Phi @ wminus) + np.ones((Phi.shape[1], 1)) * lmbd     

    return gradwplus, gradwminus



def ProjectionPositiveOrthant(x):
    ''' returns the projection of x onto the positive orthant such that it is element of convex set

    for the derivation of the analytical expression of the projection, please refer to the pdf (part a.2): y_i = max{0, x_i}
    '''
    
    y = np.where(x < 0, 0, x) 
    return y



def getStepSize(wplus, wminus, Phi, Y, lmbd, gradwplus, gradwminus, loss):
    ''' performs one step of projected gradient descent (i.e.
    compute next iterate) with step size selection via
    backtracking line search

    input
    loss: objective function at current iterate (wplus, wminus)

    output
    wplusnew, wminusnew: next iterates wplus_{t+1}, wminus_{t+1}
    lossnew: objective function at the new iterate
    '''

    alpha, beta, sigma = 1., .1, .1 # initialize parameters
    wplusnew, wminusnew = wplus.copy(), wminus.copy() # create copies
    lossnew = np.float('Inf') # make sure to enter the loop

    # choose the step size alpha with backtracking line search
    while lossnew > loss + sigma * ((gradwplus * (wplusnew - wplus)).sum() + (gradwminus * (wminusnew - wminus)).sum()):

        # get new step size to test (decreasing with each step)
        alpha *= beta

        # projected gradient step for wplus and wminus with step size alpha
        # i.e. compute x_{t+1} as in the text
        wplusnew = ProjectionPositiveOrthant(wplus - alpha*gradwplus)
        wminusnew = ProjectionPositiveOrthant(wminus - alpha*gradwminus)

        # compute new value of the objective
        lossnew = LassoObjective(wplusnew, wminusnew, Phi, Y, lmbd)

    return wplusnew, wminusnew, lossnew

# %% [markdown]
# *2)*

# %%
# scale training and test data by the mean and standard deviations in the training data set

means = np.mean(X_train, axis = 0)
stds = np.std(X_train, axis = 0)

X_train_scaled = (X_train - means) / stds
X_test_scaled = (X_test - means) / stds

# %%
# add offset parameter as feature by adding a column of ones

X_train_offset = np.c_[ X_train_scaled, np.ones(X_train_scaled.shape[0]) ]
X_test_offset = np.c_[ X_test_scaled, np.ones(X_test_scaled.shape[0]) ]

# %%
# run Lasso implementation

w = Lasso(X_train_offset, Y_train, 10)
# Out:
# iter=100 current objective=139276.556 nonzero weights=53 stop=0.12160
# iter=200 current objective=138924.624 nonzero weights=47 stop=0.04654
# iter=300 current objective=138832.739 nonzero weights=44 stop=0.00568
# iter=400 current objective=138786.721 nonzero weights=43 stop=0.00400
# iter=500 current objective=138758.189 nonzero weights=43 stop=0.00305
# iter=600 current objective=138738.643 nonzero weights=42 stop=0.00240
# iter=700 current objective=138724.476 nonzero weights=42 stop=0.00194
# iter=800 current objective=138716.255 nonzero weights=41 stop=0.00125
# iter=900 current objective=138714.444 nonzero weights=41 stop=0.00078
# iter=1000 current objective=138713.816 nonzero weights=40 stop=0.00048
# iter=1100 current objective=138713.590 nonzero weights=40 stop=0.00030
# iter=1200 current objective=138713.507 nonzero weights=40 stop=0.00018
# iter=1300 current objective=138713.476 nonzero weights=40 stop=0.00011
# iter=1400 current objective=138713.464 nonzero weights=40 stop=0.00007
# iter=1500 current objective=138713.460 nonzero weights=40 stop=0.00004
# iter=1600 current objective=138713.458 nonzero weights=40 stop=0.00003
# iter=1700 current objective=138713.458 nonzero weights=40 stop=0.00002
# iter=1800 current objective=138713.457 nonzero weights=40 stop=0.00001
# iter=1900 current objective=138713.457 nonzero weights=40 stop=0.00001

# %%
# i. compute and report training and test loss

training_loss = ((X_train_offset @ w - Y_train) ** 2).mean()
test_loss = ((X_test_offset @ w - Y_test) ** 2).mean()

print('Training loss = {:.5f} \nTest loss = {:.5f}'.format(training_loss, test_loss))
# Out:
# Training loss = 121332.09637
# Test loss = 153261.52154

# %%
# ii. plot predicted vs. true values for test set

plt.plot(X_test_offset @ w, Y_test, '.')
plt.plot(range(0, 3000), range(0, 3000))
plt.show()

# %% [markdown]
# Here, one can observe our model (x-axis) also predicts a negative output in seven cases which is not reasonable since this denotes the number of violent crimes per 100K population. This might be the case because 22 out of the 100 weights are negative.
#
# In addition, it can be seen that our model finds a good balance between under- and overestimating the output. Also, it works very well for small outputs but as the output grows, the deviation from the true output increases.

# %%
print(np.sum(np.array(w) < 0))
print(np.sum(X_test_offset @ w < 0))
# Out:
# 22
# 7

# %% [markdown]
# *3)*

# %%
def BasisFunction(X):
  ''' 
  function to convert the original features into the design matrix using 
  basis functions: X ** 2 
  - this basis function is chosen because we have seen in the plot that the
  model has difficulties predict larger outputs

  input: original features (n*100)
  output design matrix (n*200)
  '''

  X_design = np.c_[ X, X ** 2 ]

  return X_design



def train_model():
  '''
  - function to train the model based on the normalized training data with offset 
  parameters
  - the optimal regularization parameter lambda is determined via cross-validation
  using the test data as the validation data
  - the function returns the optimal weights and the means and standard deviations
  used for scaling
  '''

  np.random.seed(2) # to ensure replicable results

  means = np.mean(X_train, axis = 0)
  stds = np.std(X_train, axis = 0)

  X_train_scaled = (X_train - means) / stds
  X_test_scaled = (X_test - means) / stds

  X_train_basis = BasisFunction(X_train_scaled)
  X_test_basis = BasisFunction(X_test_scaled)

  X_train_offset = np.c_[ X_train_basis, np.ones(X_train_basis.shape[0]) ]
  X_test_offset = np.c_[ X_test_basis, np.ones(X_test_basis.shape[0]) ]

  # determine lambda via cross-validation 
  # note: the range of labmda is already pre-selected by initial 
  # cross-validations to reduce the runtime
  min_lmbda = 95
  max_lmbda = 99
  range_lbmda = [i for i in range(min_lmbda, max_lmbda)]
  test_loss = np.zeros(len(range_lbmda))
  w_test = list()
  c = 0

  for l in range_lbmda:
    print('\nFor lmbda = {}:'.format(l))
    w_test.append(Lasso(X_train_offset, Y_train, l))
    test_loss[c] = ((X_test_offset @ w_test - Y_test) ** 2).mean()
    c += 1

  ind = np.argmin(test_loss)
  w = w_test[ind]
  print('\nBest lambda via cross-validation: lmbda = {}'.format(range_lbmda[ind]))
  return w, means, stds



def Prediction(X):
  '''
  function to predict the output for a set of testpoints X
  - first, the model is trained via train_model()
  - second, the matrix X is prepared using scaling and our defintion of the design
  matrix
  - third, the predictions are returned
  '''

  w, means_train, stds_train = train_model()

  X_scaled = (X - means_train) / stds_train
  X_basis = BasisFunction(X_scaled)
  X_basis_offset = np.c_[ X_basis, np.ones(X_basis.shape[0]) ]

  pred = X_basis_offset @ w

  return pred

# %%
# exemplary execution on test set (training duration: roughly 2 min)
predictions = Prediction(X_test)
print('\nTest loss = {:.5f}'.format(((predictions - Y_test) ** 2).mean()))
# Out:
# For lmbda = 95:
# iter=100 current objective=274260.441 nonzero weights=145 stop=5.64593
# iter=200 current objective=255974.879 nonzero weights=93 stop=3.53775
# iter=300 current objective=244230.454 nonzero weights=70 stop=3.77705
# iter=400 current objective=234270.253 nonzero weights=51 stop=0.29167
# iter=500 current objective=228475.657 nonzero weights=41 stop=0.20160
# iter=600 current objective=225782.463 nonzero weights=38 stop=0.10470
# iter=700 current objective=224848.884 nonzero weights=33 stop=0.28002
# iter=800 current objective=224484.251 nonzero weights=32 stop=0.03842
# iter=900 current objective=224314.992 nonzero weights=31 stop=0.03941
# iter=1000 current objective=224207.874 nonzero weights=29 stop=0.02061
# iter=1100 current objective=224168.586 nonzero weights=29 stop=0.01131
# iter=1200 current objective=224147.790 nonzero weights=29 stop=0.01472
# iter=1300 current objective=224136.304 nonzero weights=28 stop=0.00554
# iter=1400 current objective=224130.548 nonzero weights=27 stop=0.01063
# iter=1500 current objective=224127.736 nonzero weights=27 stop=0.00288
# iter=1600 current objective=224126.143 nonzero weights=27 stop=0.00199
# iter=1700 current objective=224125.039 nonzero weights=27 stop=0.00677
# iter=1800 current objective=224124.198 nonzero weights=27 stop=0.00332
# iter=1900 current objective=224123.457 nonzero weights=27 stop=0.00501
# iter=2000 current objective=224122.764 nonzero weights=27 stop=0.00151
# iter=2100 current objective=224122.092 nonzero weights=27 stop=0.00436
# iter=2200 current objective=224121.430 nonzero weights=27 stop=0.00115
# iter=2300 current objective=224120.777 nonzero weights=26 stop=0.00348
# iter=2400 current objective=224120.255 nonzero weights=26 stop=0.00088
# iter=2500 current objective=224119.757 nonzero weights=26 stop=0.00183
# iter=2600 current objective=224119.314 nonzero weights=26 stop=0.00232
# iter=2700 current objective=224118.908 nonzero weights=26 stop=0.00092
# iter=2800 current objective=224118.531 nonzero weights=26 stop=0.00203
# iter=2900 current objective=224118.184 nonzero weights=26 stop=0.00071
# iter=3000 current objective=224117.861 nonzero weights=26 stop=0.00169
# iter=3100 current objective=224117.564 nonzero weights=26 stop=0.00061
# iter=3200 current objective=224117.276 nonzero weights=26 stop=0.00115
# iter=3300 current objective=224117.021 nonzero weights=26 stop=0.00117
# iter=3400 current objective=224116.787 nonzero weights=26 stop=0.00064
# iter=3500 current objective=224116.570 nonzero weights=26 stop=0.00104
# iter=3600 current objective=224116.369 nonzero weights=26 stop=0.00051
# iter=3700 current objective=224116.179 nonzero weights=26 stop=0.00556
# iter=3800 current objective=224116.003 nonzero weights=26 stop=0.00087
# iter=3900 current objective=224115.847 nonzero weights=26 stop=0.00468
# iter=4000 current objective=224115.698 nonzero weights=26 stop=0.00067
# iter=4100 current objective=224115.563 nonzero weights=26 stop=0.00045
# iter=4200 current objective=224115.435 nonzero weights=26 stop=0.00324
# iter=4300 current objective=224115.318 nonzero weights=26 stop=0.00133
# iter=4400 current objective=224115.210 nonzero weights=26 stop=0.00241
# iter=4500 current objective=224115.111 nonzero weights=26 stop=0.00055
# iter=4600 current objective=224115.019 nonzero weights=26 stop=0.00049
# iter=4700 current objective=224114.935 nonzero weights=26 stop=0.00042
# iter=4800 current objective=224114.857 nonzero weights=26 stop=0.00167
# iter=4900 current objective=224114.782 nonzero weights=26 stop=0.00147
# iter=5000 current objective=224114.714 nonzero weights=26 stop=0.00080
# iter=5100 current objective=224114.652 nonzero weights=26 stop=0.00109
# iter=5200 current objective=224114.595 nonzero weights=26 stop=0.00037
# iter=5300 current objective=224114.542 nonzero weights=26 stop=0.00094
# iter=5400 current objective=224114.494 nonzero weights=26 stop=0.00028
# iter=5500 current objective=224114.449 nonzero weights=26 stop=0.00078
# iter=5600 current objective=224114.405 nonzero weights=26 stop=0.00071
# iter=5700 current objective=224114.366 nonzero weights=26 stop=0.00049
# iter=5800 current objective=224114.331 nonzero weights=26 stop=0.00053
# iter=5900 current objective=224114.298 nonzero weights=26 stop=0.00026
# iter=6000 current objective=224114.267 nonzero weights=26 stop=0.00046
# iter=6100 current objective=224114.239 nonzero weights=26 stop=0.00020
# iter=6200 current objective=224114.213 nonzero weights=26 stop=0.00039
# iter=6300 current objective=224114.189 nonzero weights=26 stop=0.00017
# iter=6400 current objective=224114.166 nonzero weights=26 stop=0.00229
# iter=6500 current objective=224114.146 nonzero weights=26 stop=0.00015
# iter=6600 current objective=224114.126 nonzero weights=26 stop=0.00018
# iter=6700 current objective=224114.109 nonzero weights=26 stop=0.00025
# iter=6800 current objective=224114.092 nonzero weights=26 stop=0.00014
# iter=6900 current objective=224114.077 nonzero weights=26 stop=0.00117
# iter=7000 current objective=224114.063 nonzero weights=26 stop=0.00023
# iter=7100 current objective=224114.050 nonzero weights=26 stop=0.00020
# iter=7200 current objective=224114.038 nonzero weights=26 stop=0.00017
# iter=7300 current objective=224114.027 nonzero weights=26 stop=0.00013
# iter=7400 current objective=224114.017 nonzero weights=26 stop=0.00070
# iter=7500 current objective=224114.007 nonzero weights=26 stop=0.00035
# iter=7600 current objective=224113.998 nonzero weights=26 stop=0.00052
# iter=7700 current objective=224113.990 nonzero weights=26 stop=0.00015
# iter=7800 current objective=224113.983 nonzero weights=26 stop=0.00044
# iter=7900 current objective=224113.976 nonzero weights=26 stop=0.00011
# iter=8000 current objective=224113.970 nonzero weights=26 stop=0.00036
# iter=8100 current objective=224113.964 nonzero weights=26 stop=0.00009
# iter=8200 current objective=224113.958 nonzero weights=26 stop=0.00021
# iter=8300 current objective=224113.953 nonzero weights=26 stop=0.00024
# iter=8400 current objective=224113.949 nonzero weights=26 stop=0.00010
# iter=8500 current objective=224113.944 nonzero weights=26 stop=0.00021
# iter=8600 current objective=224113.940 nonzero weights=26 stop=0.00008
# iter=8700 current objective=224113.937 nonzero weights=26 stop=0.00017
# iter=8800 current objective=224113.933 nonzero weights=26 stop=0.00006
# iter=8900 current objective=224113.930 nonzero weights=26 stop=0.00015
# iter=9000 current objective=224113.927 nonzero weights=26 stop=0.00012
# iter=9100 current objective=224113.925 nonzero weights=26 stop=0.00007
# iter=9200 current objective=224113.922 nonzero weights=26 stop=0.00011
# iter=9300 current objective=224113.920 nonzero weights=26 stop=0.00005
# iter=9400 current objective=224113.918 nonzero weights=26 stop=0.00057
# iter=9500 current objective=224113.916 nonzero weights=26 stop=0.00010
# iter=9600 current objective=224113.914 nonzero weights=26 stop=0.00048
# iter=9700 current objective=224113.912 nonzero weights=26 stop=0.00007
# iter=9800 current objective=224113.911 nonzero weights=26 stop=0.00005
# iter=9900 current objective=224113.909 nonzero weights=26 stop=0.00034
# iter=10000 current objective=224113.908 nonzero weights=26 stop=0.00015
# iter=10100 current objective=224113.907 nonzero weights=26 stop=0.00025
# iter=10200 current objective=224113.906 nonzero weights=26 stop=0.00006
# iter=10300 current objective=224113.904 nonzero weights=26 stop=0.00021
# iter=10400 current objective=224113.904 nonzero weights=26 stop=0.00005
# iter=10500 current objective=224113.903 nonzero weights=26 stop=0.00017
# iter=10600 current objective=224113.902 nonzero weights=26 stop=0.00015
# iter=10700 current objective=224113.901 nonzero weights=26 stop=0.00009
# iter=10800 current objective=224113.900 nonzero weights=26 stop=0.00011
# iter=10900 current objective=224113.900 nonzero weights=26 stop=0.00004
# iter=11000 current objective=224113.899 nonzero weights=26 stop=0.00010
# iter=11100 current objective=224113.899 nonzero weights=26 stop=0.00003
# iter=11200 current objective=224113.898 nonzero weights=26 stop=0.00008
# iter=11300 current objective=224113.898 nonzero weights=26 stop=0.00003
# iter=11400 current objective=224113.897 nonzero weights=26 stop=0.00006
# iter=11500 current objective=224113.897 nonzero weights=26 stop=0.00005
# iter=11600 current objective=224113.896 nonzero weights=26 stop=0.00003
# iter=11700 current objective=224113.896 nonzero weights=26 stop=0.00005
# iter=11800 current objective=224113.896 nonzero weights=26 stop=0.00002
# iter=11900 current objective=224113.895 nonzero weights=26 stop=0.00028
# iter=12000 current objective=224113.895 nonzero weights=26 stop=0.00002
# iter=12100 current objective=224113.895 nonzero weights=26 stop=0.00024
# iter=12200 current objective=224113.895 nonzero weights=26 stop=0.00003
# iter=12300 current objective=224113.894 nonzero weights=26 stop=0.00002
# iter=12400 current objective=224113.894 nonzero weights=26 stop=0.00003
# iter=12500 current objective=224113.894 nonzero weights=26 stop=0.00002
# iter=12600 current objective=224113.894 nonzero weights=26 stop=0.00012
# iter=12700 current objective=224113.894 nonzero weights=26 stop=0.00003
# iter=12800 current objective=224113.893 nonzero weights=26 stop=0.00002
# iter=12900 current objective=224113.893 nonzero weights=26 stop=0.00002
# iter=13000 current objective=224113.893 nonzero weights=26 stop=0.00001
# iter=13100 current objective=224113.893 nonzero weights=26 stop=0.00007
# iter=13200 current objective=224113.893 nonzero weights=26 stop=0.00004
# iter=13300 current objective=224113.893 nonzero weights=26 stop=0.00005
# iter=13400 current objective=224113.893 nonzero weights=26 stop=0.00002
# iter=13500 current objective=224113.893 nonzero weights=26 stop=0.00005
# iter=13600 current objective=224113.893 nonzero weights=26 stop=0.00001
# iter=13700 current objective=224113.893 nonzero weights=26 stop=0.00004
# iter=13800 current objective=224113.893 nonzero weights=26 stop=0.00001
#
# For lmbda = 96:
# iter=100 current objective=275737.990 nonzero weights=143 stop=5.92140
# iter=200 current objective=256784.844 nonzero weights=87 stop=3.83922
# iter=300 current objective=245275.784 nonzero weights=66 stop=0.69439
# iter=400 current objective=233680.045 nonzero weights=46 stop=0.24225
# iter=500 current objective=228617.015 nonzero weights=39 stop=0.14617
# iter=600 current objective=226469.989 nonzero weights=37 stop=0.34326
# iter=700 current objective=225647.523 nonzero weights=33 stop=0.08360
# iter=800 current objective=225355.847 nonzero weights=32 stop=0.07655
# iter=900 current objective=225201.774 nonzero weights=30 stop=0.02572
# iter=1000 current objective=225109.952 nonzero weights=29 stop=0.01842
# iter=1100 current objective=225075.657 nonzero weights=29 stop=0.01271
# iter=1200 current objective=225057.118 nonzero weights=29 stop=0.00914
# iter=1300 current objective=225047.197 nonzero weights=27 stop=0.00570
# iter=1400 current objective=225042.589 nonzero weights=27 stop=0.00548
# iter=1500 current objective=225040.216 nonzero weights=27 stop=0.00259
# iter=1600 current objective=225038.792 nonzero weights=27 stop=0.00396
# iter=1700 current objective=225037.787 nonzero weights=27 stop=0.00161
# iter=1800 current objective=225036.960 nonzero weights=27 stop=0.00305
# iter=1900 current objective=225036.217 nonzero weights=27 stop=0.00117
# iter=2000 current objective=225035.476 nonzero weights=27 stop=0.00198
# iter=2100 current objective=225034.782 nonzero weights=27 stop=0.00209
# iter=2200 current objective=225034.145 nonzero weights=26 stop=0.00098
# iter=2300 current objective=225033.617 nonzero weights=26 stop=0.00168
# iter=2400 current objective=225033.135 nonzero weights=26 stop=0.00078
# iter=2500 current objective=225032.679 nonzero weights=26 stop=0.00934
# iter=2600 current objective=225032.255 nonzero weights=26 stop=0.00138
# iter=2700 current objective=225031.881 nonzero weights=26 stop=0.00785
# iter=2800 current objective=225031.521 nonzero weights=26 stop=0.00108
# iter=2900 current objective=225031.197 nonzero weights=26 stop=0.00070
# iter=3000 current objective=225030.890 nonzero weights=26 stop=0.00539
# iter=3100 current objective=225030.606 nonzero weights=26 stop=0.00210
# iter=3200 current objective=225030.348 nonzero weights=26 stop=0.00405
# iter=3300 current objective=225030.109 nonzero weights=26 stop=0.00086
# iter=3400 current objective=225029.890 nonzero weights=26 stop=0.00077
# iter=3500 current objective=225029.686 nonzero weights=26 stop=0.00067
# iter=3600 current objective=225029.498 nonzero weights=26 stop=0.00050
# iter=3700 current objective=225029.318 nonzero weights=26 stop=0.00245
# iter=3800 current objective=225029.157 nonzero weights=26 stop=0.00125
# iter=3900 current objective=225029.008 nonzero weights=26 stop=0.00183
# iter=4000 current objective=225028.871 nonzero weights=26 stop=0.00058
# iter=4100 current objective=225028.744 nonzero weights=26 stop=0.00157
# iter=4200 current objective=225028.626 nonzero weights=26 stop=0.00045
# iter=4300 current objective=225028.518 nonzero weights=26 stop=0.00129
# iter=4400 current objective=225028.413 nonzero weights=26 stop=0.00117
# iter=4500 current objective=225028.321 nonzero weights=26 stop=0.00077
# iter=4600 current objective=225028.235 nonzero weights=26 stop=0.00088
# iter=4700 current objective=225028.156 nonzero weights=26 stop=0.00040
# iter=4800 current objective=225028.082 nonzero weights=26 stop=0.00077
# iter=4900 current objective=225028.015 nonzero weights=26 stop=0.00031
# iter=5000 current objective=225027.952 nonzero weights=26 stop=0.00064
# iter=5100 current objective=225027.894 nonzero weights=26 stop=0.00026
# iter=5200 current objective=225027.840 nonzero weights=26 stop=0.00385
# iter=5300 current objective=225027.789 nonzero weights=26 stop=0.00046
# iter=5400 current objective=225027.743 nonzero weights=26 stop=0.00028
# iter=5500 current objective=225027.701 nonzero weights=26 stop=0.00041
# iter=5600 current objective=225027.662 nonzero weights=26 stop=0.00022
# iter=5700 current objective=225027.624 nonzero weights=26 stop=0.00196
# iter=5800 current objective=225027.591 nonzero weights=26 stop=0.00036
# iter=5900 current objective=225027.560 nonzero weights=26 stop=0.00031
# iter=6000 current objective=225027.531 nonzero weights=26 stop=0.00028
# iter=6100 current objective=225027.505 nonzero weights=26 stop=0.00020
# iter=6200 current objective=225027.480 nonzero weights=26 stop=0.00117
# iter=6300 current objective=225027.457 nonzero weights=26 stop=0.00055
# iter=6400 current objective=225027.436 nonzero weights=26 stop=0.00087
# iter=6500 current objective=225027.417 nonzero weights=26 stop=0.00024
# iter=6600 current objective=225027.399 nonzero weights=26 stop=0.00074
# iter=6700 current objective=225027.383 nonzero weights=26 stop=0.00018
# iter=6800 current objective=225027.367 nonzero weights=26 stop=0.00061
# iter=6900 current objective=225027.353 nonzero weights=26 stop=0.00015
# iter=7000 current objective=225027.340 nonzero weights=26 stop=0.00033
# iter=7100 current objective=225027.328 nonzero weights=26 stop=0.00040
# iter=7200 current objective=225027.317 nonzero weights=26 stop=0.00016
# iter=7300 current objective=225027.306 nonzero weights=26 stop=0.00035
# iter=7400 current objective=225027.297 nonzero weights=26 stop=0.00012
# iter=7500 current objective=225027.288 nonzero weights=26 stop=0.00029
# iter=7600 current objective=225027.280 nonzero weights=26 stop=0.00010
# iter=7700 current objective=225027.272 nonzero weights=26 stop=0.00020
# iter=7800 current objective=225027.265 nonzero weights=26 stop=0.00020
# iter=7900 current objective=225027.259 nonzero weights=26 stop=0.00011
# iter=8000 current objective=225027.253 nonzero weights=26 stop=0.00018
# iter=8100 current objective=225027.247 nonzero weights=26 stop=0.00009
# iter=8200 current objective=225027.242 nonzero weights=26 stop=0.00096
# iter=8300 current objective=225027.237 nonzero weights=26 stop=0.00015
# iter=8400 current objective=225027.233 nonzero weights=26 stop=0.00081
# iter=8500 current objective=225027.229 nonzero weights=26 stop=0.00012
# iter=8600 current objective=225027.225 nonzero weights=26 stop=0.00065
# iter=8700 current objective=225027.222 nonzero weights=26 stop=0.00056
# iter=8800 current objective=225027.219 nonzero weights=26 stop=0.00024
# iter=8900 current objective=225027.216 nonzero weights=26 stop=0.00042
# iter=9000 current objective=225027.213 nonzero weights=26 stop=0.00010
# iter=9100 current objective=225027.210 nonzero weights=26 stop=0.00009
# iter=9200 current objective=225027.208 nonzero weights=26 stop=0.00007
# iter=9300 current objective=225027.206 nonzero weights=26 stop=0.00029
# iter=9400 current objective=225027.204 nonzero weights=26 stop=0.00026
# iter=9500 current objective=225027.202 nonzero weights=26 stop=0.00014
# iter=9600 current objective=225027.200 nonzero weights=26 stop=0.00019
# iter=9700 current objective=225027.199 nonzero weights=26 stop=0.00006
# iter=9800 current objective=225027.197 nonzero weights=26 stop=0.00016
# iter=9900 current objective=225027.196 nonzero weights=26 stop=0.00005
# iter=10000 current objective=225027.195 nonzero weights=26 stop=0.00013
# iter=10100 current objective=225027.194 nonzero weights=26 stop=0.00004
# iter=10200 current objective=225027.193 nonzero weights=26 stop=0.00009
# iter=10300 current objective=225027.192 nonzero weights=26 stop=0.00009
# iter=10400 current objective=225027.191 nonzero weights=26 stop=0.00004
# iter=10500 current objective=225027.190 nonzero weights=26 stop=0.00008
# iter=10600 current objective=225027.189 nonzero weights=26 stop=0.00003
# iter=10700 current objective=225027.188 nonzero weights=26 stop=0.00007
# iter=10800 current objective=225027.188 nonzero weights=26 stop=0.00003
# iter=10900 current objective=225027.187 nonzero weights=26 stop=0.00040
# iter=11000 current objective=225027.187 nonzero weights=26 stop=0.00003
# iter=11100 current objective=225027.186 nonzero weights=26 stop=0.00003
# iter=11200 current objective=225027.186 nonzero weights=26 stop=0.00004
# iter=11300 current objective=225027.185 nonzero weights=26 stop=0.00002
# iter=11400 current objective=225027.185 nonzero weights=26 stop=0.00020
# iter=11500 current objective=225027.184 nonzero weights=26 stop=0.00004
# iter=11600 current objective=225027.184 nonzero weights=26 stop=0.00004
# iter=11700 current objective=225027.184 nonzero weights=26 stop=0.00003
# iter=11800 current objective=225027.183 nonzero weights=26 stop=0.00002
# iter=11900 current objective=225027.183 nonzero weights=26 stop=0.00012
# iter=12000 current objective=225027.183 nonzero weights=26 stop=0.00006
# iter=12100 current objective=225027.183 nonzero weights=26 stop=0.00009
# iter=12200 current objective=225027.182 nonzero weights=26 stop=0.00003
# iter=12300 current objective=225027.182 nonzero weights=26 stop=0.00008
# iter=12400 current objective=225027.182 nonzero weights=26 stop=0.00002
# iter=12500 current objective=225027.182 nonzero weights=26 stop=0.00006
# iter=12600 current objective=225027.182 nonzero weights=26 stop=0.00002
# iter=12700 current objective=225027.182 nonzero weights=26 stop=0.00004
# iter=12800 current objective=225027.181 nonzero weights=26 stop=0.00004
# iter=12900 current objective=225027.181 nonzero weights=26 stop=0.00002
# iter=13000 current objective=225027.181 nonzero weights=26 stop=0.00004
# iter=13100 current objective=225027.181 nonzero weights=26 stop=0.00001
# iter=13200 current objective=225027.181 nonzero weights=26 stop=0.00003
# iter=13300 current objective=225027.181 nonzero weights=26 stop=0.00001
# iter=13400 current objective=225027.181 nonzero weights=26 stop=0.00002
# iter=13500 current objective=225027.181 nonzero weights=26 stop=0.00002
# iter=13600 current objective=225027.181 nonzero weights=26 stop=0.00001
# iter=13700 current objective=225027.181 nonzero weights=26 stop=0.00002
# iter=13800 current objective=225027.180 nonzero weights=26 stop=0.00001
#
# For lmbda = 97:
# iter=100 current objective=275157.586 nonzero weights=142 stop=5.47007
# iter=200 current objective=256284.195 nonzero weights=84 stop=1.33599
# iter=300 current objective=246593.826 nonzero weights=61 stop=0.52843
# iter=400 current objective=237523.853 nonzero weights=52 stop=0.38787
# iter=500 current objective=231009.566 nonzero weights=45 stop=0.38824
# iter=600 current objective=227717.233 nonzero weights=39 stop=0.12115
# iter=700 current objective=226686.296 nonzero weights=34 stop=0.06424
# iter=800 current objective=226316.695 nonzero weights=32 stop=0.02837
# iter=900 current objective=226135.629 nonzero weights=30 stop=0.04463
# iter=1000 current objective=226031.141 nonzero weights=29 stop=0.01113
# iter=1100 current objective=225990.459 nonzero weights=29 stop=0.01758
# iter=1200 current objective=225969.148 nonzero weights=29 stop=0.00688
# iter=1300 current objective=225957.532 nonzero weights=28 stop=0.00759
# iter=1400 current objective=225952.493 nonzero weights=27 stop=0.00927
# iter=1500 current objective=225949.917 nonzero weights=27 stop=0.00314
# iter=1600 current objective=225948.398 nonzero weights=27 stop=0.00723
# iter=1700 current objective=225947.335 nonzero weights=27 stop=0.00191
# iter=1800 current objective=225946.475 nonzero weights=27 stop=0.00571
# iter=1900 current objective=225945.676 nonzero weights=27 stop=0.00508
# iter=2000 current objective=225944.939 nonzero weights=27 stop=0.00296
# iter=2100 current objective=225944.321 nonzero weights=26 stop=0.00358
# iter=2200 current objective=225943.790 nonzero weights=26 stop=0.00121
# iter=2300 current objective=225943.302 nonzero weights=26 stop=0.00308
# iter=2400 current objective=225942.852 nonzero weights=26 stop=0.00088
# iter=2500 current objective=225942.437 nonzero weights=26 stop=0.00253
# iter=2600 current objective=225942.053 nonzero weights=26 stop=0.00073
# iter=2700 current objective=225941.698 nonzero weights=26 stop=0.00213
# iter=2800 current objective=225941.354 nonzero weights=26 stop=0.00170
# iter=2900 current objective=225941.052 nonzero weights=26 stop=0.00083
# iter=3000 current objective=225940.771 nonzero weights=26 stop=0.00150
# iter=3100 current objective=225940.513 nonzero weights=26 stop=0.00061
# iter=3200 current objective=225940.273 nonzero weights=26 stop=0.00125
# iter=3300 current objective=225940.052 nonzero weights=26 stop=0.00051
# iter=3400 current objective=225939.845 nonzero weights=26 stop=0.00765
# iter=3500 current objective=225939.648 nonzero weights=26 stop=0.00093
# iter=3600 current objective=225939.473 nonzero weights=26 stop=0.00057
# iter=3700 current objective=225939.311 nonzero weights=26 stop=0.00079
# iter=3800 current objective=225939.162 nonzero weights=26 stop=0.00044
# iter=3900 current objective=225939.020 nonzero weights=26 stop=0.00387
# iter=4000 current objective=225938.890 nonzero weights=26 stop=0.00077
# iter=4100 current objective=225938.772 nonzero weights=26 stop=0.00067
# iter=4200 current objective=225938.663 nonzero weights=26 stop=0.00056
# iter=4300 current objective=225938.562 nonzero weights=26 stop=0.00040
# iter=4400 current objective=225938.467 nonzero weights=26 stop=0.00234
# iter=4500 current objective=225938.380 nonzero weights=26 stop=0.00121
# iter=4600 current objective=225938.299 nonzero weights=26 stop=0.00170
# iter=4700 current objective=225938.226 nonzero weights=26 stop=0.00050
# iter=4800 current objective=225938.158 nonzero weights=26 stop=0.00146
# iter=4900 current objective=225938.095 nonzero weights=26 stop=0.00036
# iter=5000 current objective=225938.036 nonzero weights=26 stop=0.00119
# iter=5100 current objective=225937.983 nonzero weights=26 stop=0.00029
# iter=5200 current objective=225937.931 nonzero weights=26 stop=0.00072
# iter=5300 current objective=225937.885 nonzero weights=26 stop=0.00079
# iter=5400 current objective=225937.842 nonzero weights=26 stop=0.00034
# iter=5500 current objective=225937.803 nonzero weights=26 stop=0.00069
# iter=5600 current objective=225937.767 nonzero weights=26 stop=0.00024
# iter=5700 current objective=225937.733 nonzero weights=26 stop=0.00057
# iter=5800 current objective=225937.702 nonzero weights=26 stop=0.00020
# iter=5900 current objective=225937.672 nonzero weights=26 stop=0.00044
# iter=6000 current objective=225937.645 nonzero weights=26 stop=0.00040
# iter=6100 current objective=225937.621 nonzero weights=26 stop=0.00023
# iter=6200 current objective=225937.598 nonzero weights=26 stop=0.00035
# iter=6300 current objective=225937.577 nonzero weights=26 stop=0.00017
# iter=6400 current objective=225937.557 nonzero weights=26 stop=0.00190
# iter=6500 current objective=225937.539 nonzero weights=26 stop=0.00032
# iter=6600 current objective=225937.523 nonzero weights=26 stop=0.00160
# iter=6700 current objective=225937.507 nonzero weights=26 stop=0.00023
# iter=6800 current objective=225937.493 nonzero weights=26 stop=0.00129
# iter=6900 current objective=225937.480 nonzero weights=26 stop=0.00019
# iter=7000 current objective=225937.468 nonzero weights=26 stop=0.00054
# iter=7100 current objective=225937.456 nonzero weights=26 stop=0.00082
# iter=7200 current objective=225937.446 nonzero weights=26 stop=0.00021
# iter=7300 current objective=225937.436 nonzero weights=26 stop=0.00018
# iter=7400 current objective=225937.427 nonzero weights=26 stop=0.00015
# iter=7500 current objective=225937.419 nonzero weights=26 stop=0.00057
# iter=7600 current objective=225937.412 nonzero weights=26 stop=0.00051
# iter=7700 current objective=225937.404 nonzero weights=26 stop=0.00032
# iter=7800 current objective=225937.398 nonzero weights=26 stop=0.00037
# iter=7900 current objective=225937.392 nonzero weights=26 stop=0.00014
# iter=8000 current objective=225937.386 nonzero weights=26 stop=0.00032
# iter=8100 current objective=225937.381 nonzero weights=26 stop=0.00010
# iter=8200 current objective=225937.377 nonzero weights=26 stop=0.00026
# iter=8300 current objective=225937.372 nonzero weights=26 stop=0.00008
# iter=8400 current objective=225937.368 nonzero weights=26 stop=0.00022
# iter=8500 current objective=225937.364 nonzero weights=26 stop=0.00018
# iter=8600 current objective=225937.361 nonzero weights=26 stop=0.00009
# iter=8700 current objective=225937.358 nonzero weights=26 stop=0.00016
# iter=8800 current objective=225937.355 nonzero weights=26 stop=0.00007
# iter=8900 current objective=225937.352 nonzero weights=26 stop=0.00013
# iter=9000 current objective=225937.350 nonzero weights=26 stop=0.00005
# iter=9100 current objective=225937.347 nonzero weights=26 stop=0.00079
# iter=9200 current objective=225937.345 nonzero weights=26 stop=0.00005
# iter=9300 current objective=225937.343 nonzero weights=26 stop=0.00006
# iter=9400 current objective=225937.341 nonzero weights=26 stop=0.00008
# iter=9500 current objective=225937.340 nonzero weights=26 stop=0.00005
# iter=9600 current objective=225937.338 nonzero weights=26 stop=0.00040
# iter=9700 current objective=225937.336 nonzero weights=26 stop=0.00009
# iter=9800 current objective=225937.335 nonzero weights=26 stop=0.00008
# iter=9900 current objective=225937.334 nonzero weights=26 stop=0.00006
# iter=10000 current objective=225937.333 nonzero weights=26 stop=0.00004
# iter=10100 current objective=225937.332 nonzero weights=26 stop=0.00024
# iter=10200 current objective=225937.331 nonzero weights=26 stop=0.00014
# iter=10300 current objective=225937.330 nonzero weights=26 stop=0.00017
# iter=10400 current objective=225937.329 nonzero weights=26 stop=0.00006
# iter=10500 current objective=225937.328 nonzero weights=26 stop=0.00015
# iter=10600 current objective=225937.327 nonzero weights=26 stop=0.00004
# iter=10700 current objective=225937.327 nonzero weights=26 stop=0.00012
# iter=10800 current objective=225937.326 nonzero weights=26 stop=0.00003
# iter=10900 current objective=225937.326 nonzero weights=26 stop=0.00008
# iter=11000 current objective=225937.325 nonzero weights=26 stop=0.00008
# iter=11100 current objective=225937.325 nonzero weights=26 stop=0.00004
# iter=11200 current objective=225937.324 nonzero weights=26 stop=0.00007
# iter=11300 current objective=225937.324 nonzero weights=26 stop=0.00003
# iter=11400 current objective=225937.323 nonzero weights=26 stop=0.00006
# iter=11500 current objective=225937.323 nonzero weights=26 stop=0.00002
# iter=11600 current objective=225937.323 nonzero weights=26 stop=0.00005
# iter=11700 current objective=225937.322 nonzero weights=26 stop=0.00004
# iter=11800 current objective=225937.322 nonzero weights=26 stop=0.00003
# iter=11900 current objective=225937.322 nonzero weights=26 stop=0.00004
# iter=12000 current objective=225937.321 nonzero weights=26 stop=0.00002
# iter=12100 current objective=225937.321 nonzero weights=26 stop=0.00019
# iter=12200 current objective=225937.321 nonzero weights=26 stop=0.00004
# iter=12300 current objective=225937.321 nonzero weights=26 stop=0.00016
# iter=12400 current objective=225937.321 nonzero weights=26 stop=0.00003
# iter=12500 current objective=225937.321 nonzero weights=26 stop=0.00002
# iter=12600 current objective=225937.320 nonzero weights=26 stop=0.00002
# iter=12700 current objective=225937.320 nonzero weights=26 stop=0.00001
# iter=12800 current objective=225937.320 nonzero weights=26 stop=0.00008
# iter=12900 current objective=225937.320 nonzero weights=26 stop=0.00002
# iter=13000 current objective=225937.320 nonzero weights=26 stop=0.00007
# iter=13100 current objective=225937.320 nonzero weights=26 stop=0.00002
# iter=13200 current objective=225937.320 nonzero weights=26 stop=0.00006
# iter=13300 current objective=225937.320 nonzero weights=26 stop=0.00005
# iter=13400 current objective=225937.320 nonzero weights=26 stop=0.00004
# iter=13500 current objective=225937.319 nonzero weights=26 stop=0.00004
# iter=13600 current objective=225937.319 nonzero weights=26 stop=0.00002
# iter=13700 current objective=225937.319 nonzero weights=26 stop=0.00003
# iter=13800 current objective=225937.319 nonzero weights=26 stop=0.00001
# iter=13900 current objective=225937.319 nonzero weights=26 stop=0.00003
# iter=14000 current objective=225937.319 nonzero weights=26 stop=0.00001
#
# For lmbda = 98:
# iter=100 current objective=276985.901 nonzero weights=146 stop=5.71486
# iter=200 current objective=255949.171 nonzero weights=82 stop=1.80716
# iter=300 current objective=244791.879 nonzero weights=60 stop=0.44260
# iter=400 current objective=236056.757 nonzero weights=50 stop=0.56621
# iter=500 current objective=230468.395 nonzero weights=40 stop=0.13144
# iter=600 current objective=228257.357 nonzero weights=37 stop=0.11207
# iter=700 current objective=227456.960 nonzero weights=33 stop=0.05286
# iter=800 current objective=227173.553 nonzero weights=32 stop=0.13539
# iter=900 current objective=227019.200 nonzero weights=30 stop=0.01788
# iter=1000 current objective=226925.315 nonzero weights=29 stop=0.01063
# iter=1100 current objective=226890.311 nonzero weights=29 stop=0.03435
# iter=1200 current objective=226871.048 nonzero weights=28 stop=0.02679
# iter=1300 current objective=226862.455 nonzero weights=28 stop=0.01042
# iter=1400 current objective=226858.315 nonzero weights=28 stop=0.02159
# iter=1500 current objective=226856.120 nonzero weights=27 stop=0.00226
# iter=1600 current objective=226854.691 nonzero weights=27 stop=0.01687
# iter=1700 current objective=226853.640 nonzero weights=27 stop=0.00253
# iter=1800 current objective=226852.789 nonzero weights=27 stop=0.00167
# iter=1900 current objective=226852.007 nonzero weights=26 stop=0.00178
# iter=2000 current objective=226851.406 nonzero weights=26 stop=0.00090
# iter=2100 current objective=226850.852 nonzero weights=26 stop=0.00917
# iter=2200 current objective=226850.346 nonzero weights=26 stop=0.00216
# iter=2300 current objective=226849.896 nonzero weights=26 stop=0.00716
# iter=2400 current objective=226849.470 nonzero weights=26 stop=0.00114
# iter=2500 current objective=226849.084 nonzero weights=26 stop=0.00087
# iter=2600 current objective=226848.725 nonzero weights=26 stop=0.00094
# iter=2700 current objective=226848.394 nonzero weights=26 stop=0.00062
# iter=2800 current objective=226848.075 nonzero weights=26 stop=0.00405
# iter=2900 current objective=226847.791 nonzero weights=26 stop=0.00131
# iter=3000 current objective=226847.530 nonzero weights=26 stop=0.00316
# iter=3100 current objective=226847.288 nonzero weights=26 stop=0.00069
# iter=3200 current objective=226847.065 nonzero weights=26 stop=0.00267
# iter=3300 current objective=226846.853 nonzero weights=26 stop=0.00310
# iter=3400 current objective=226846.660 nonzero weights=26 stop=0.00166
# iter=3500 current objective=226846.482 nonzero weights=26 stop=0.00187
# iter=3600 current objective=226846.319 nonzero weights=26 stop=0.00082
# iter=3700 current objective=226846.167 nonzero weights=26 stop=0.00147
# iter=3800 current objective=226846.028 nonzero weights=26 stop=0.00046
# iter=3900 current objective=226845.899 nonzero weights=26 stop=0.00126
# iter=4000 current objective=226845.780 nonzero weights=26 stop=0.00040
# iter=4100 current objective=226845.669 nonzero weights=26 stop=0.00105
# iter=4200 current objective=226845.568 nonzero weights=26 stop=0.00036
# iter=4300 current objective=226845.469 nonzero weights=26 stop=0.00053
# iter=4400 current objective=226845.381 nonzero weights=26 stop=0.00073
# iter=4500 current objective=226845.301 nonzero weights=26 stop=0.00033
# iter=4600 current objective=226845.227 nonzero weights=26 stop=0.00064
# iter=4700 current objective=226845.158 nonzero weights=26 stop=0.00029
# iter=4800 current objective=226845.093 nonzero weights=26 stop=0.00351
# iter=4900 current objective=226845.032 nonzero weights=26 stop=0.00049
# iter=5000 current objective=226844.978 nonzero weights=26 stop=0.00035
# iter=5100 current objective=226844.928 nonzero weights=26 stop=0.00040
# iter=5200 current objective=226844.881 nonzero weights=26 stop=0.00024
# iter=5300 current objective=226844.837 nonzero weights=26 stop=0.00195
# iter=5400 current objective=226844.797 nonzero weights=26 stop=0.00056
# iter=5500 current objective=226844.760 nonzero weights=26 stop=0.00040
# iter=5600 current objective=226844.726 nonzero weights=26 stop=0.00029
# iter=5700 current objective=226844.695 nonzero weights=26 stop=0.00024
# iter=5800 current objective=226844.666 nonzero weights=26 stop=0.00143
# iter=5900 current objective=226844.638 nonzero weights=26 stop=0.00073
# iter=6000 current objective=226844.613 nonzero weights=26 stop=0.00088
# iter=6100 current objective=226844.590 nonzero weights=26 stop=0.00034
# iter=6200 current objective=226844.569 nonzero weights=26 stop=0.00069
# iter=6300 current objective=226844.550 nonzero weights=26 stop=0.00018
# iter=6400 current objective=226844.531 nonzero weights=26 stop=0.00058
# iter=6500 current objective=226844.515 nonzero weights=26 stop=0.00016
# iter=6600 current objective=226844.499 nonzero weights=26 stop=0.00048
# iter=6700 current objective=226844.484 nonzero weights=26 stop=0.00042
# iter=6800 current objective=226844.471 nonzero weights=26 stop=0.00022
# iter=6900 current objective=226844.459 nonzero weights=26 stop=0.00033
# iter=7000 current objective=226844.448 nonzero weights=26 stop=0.00013
# iter=7100 current objective=226844.437 nonzero weights=26 stop=0.00029
# iter=7200 current objective=226844.427 nonzero weights=26 stop=0.00011
# iter=7300 current objective=226844.418 nonzero weights=26 stop=0.00024
# iter=7400 current objective=226844.410 nonzero weights=26 stop=0.00022
# iter=7500 current objective=226844.402 nonzero weights=26 stop=0.00014
# iter=7600 current objective=226844.395 nonzero weights=26 stop=0.00017
# iter=7700 current objective=226844.389 nonzero weights=26 stop=0.00009
# iter=7800 current objective=226844.383 nonzero weights=26 stop=0.00095
# iter=7900 current objective=226844.377 nonzero weights=26 stop=0.00024
# iter=8000 current objective=226844.372 nonzero weights=26 stop=0.00074
# iter=8100 current objective=226844.367 nonzero weights=26 stop=0.00012
# iter=8200 current objective=226844.363 nonzero weights=26 stop=0.00010
# iter=8300 current objective=226844.358 nonzero weights=26 stop=0.00010
# iter=8400 current objective=226844.355 nonzero weights=26 stop=0.00007
# iter=8500 current objective=226844.351 nonzero weights=26 stop=0.00042
# iter=8600 current objective=226844.348 nonzero weights=26 stop=0.00015
# iter=8700 current objective=226844.345 nonzero weights=26 stop=0.00033
# iter=8800 current objective=226844.342 nonzero weights=26 stop=0.00007
# iter=8900 current objective=226844.340 nonzero weights=26 stop=0.00028
# iter=9000 current objective=226844.337 nonzero weights=26 stop=0.00035
# iter=9100 current objective=226844.335 nonzero weights=26 stop=0.00019
# iter=9200 current objective=226844.333 nonzero weights=26 stop=0.00020
# iter=9300 current objective=226844.331 nonzero weights=26 stop=0.00009
# iter=9400 current objective=226844.329 nonzero weights=26 stop=0.00015
# iter=9500 current objective=226844.328 nonzero weights=26 stop=0.00005
# iter=9600 current objective=226844.326 nonzero weights=26 stop=0.00013
# iter=9700 current objective=226844.325 nonzero weights=26 stop=0.00004
# iter=9800 current objective=226844.324 nonzero weights=26 stop=0.00011
# iter=9900 current objective=226844.323 nonzero weights=26 stop=0.00004
# iter=10000 current objective=226844.321 nonzero weights=26 stop=0.00006
# iter=10100 current objective=226844.320 nonzero weights=26 stop=0.00008
# iter=10200 current objective=226844.320 nonzero weights=26 stop=0.00004
# iter=10300 current objective=226844.319 nonzero weights=26 stop=0.00007
# iter=10400 current objective=226844.318 nonzero weights=26 stop=0.00003
# iter=10500 current objective=226844.317 nonzero weights=26 stop=0.00036
# iter=10600 current objective=226844.316 nonzero weights=26 stop=0.00005
# iter=10700 current objective=226844.316 nonzero weights=26 stop=0.00004
# iter=10800 current objective=226844.315 nonzero weights=26 stop=0.00004
# iter=10900 current objective=226844.315 nonzero weights=26 stop=0.00003
# iter=11000 current objective=226844.314 nonzero weights=26 stop=0.00020
# iter=11100 current objective=226844.314 nonzero weights=26 stop=0.00006
# iter=11200 current objective=226844.313 nonzero weights=26 stop=0.00005
# iter=11300 current objective=226844.313 nonzero weights=26 stop=0.00003
# iter=11400 current objective=226844.313 nonzero weights=26 stop=0.00003
# iter=11500 current objective=226844.312 nonzero weights=26 stop=0.00003
# iter=11600 current objective=226844.312 nonzero weights=26 stop=0.00008
# iter=11700 current objective=226844.312 nonzero weights=26 stop=0.00009
# iter=11800 current objective=226844.311 nonzero weights=26 stop=0.00004
# iter=11900 current objective=226844.311 nonzero weights=26 stop=0.00007
# iter=12000 current objective=226844.311 nonzero weights=26 stop=0.00002
# iter=12100 current objective=226844.311 nonzero weights=26 stop=0.00006
# iter=12200 current objective=226844.311 nonzero weights=26 stop=0.00002
# iter=12300 current objective=226844.310 nonzero weights=26 stop=0.00005
# iter=12400 current objective=226844.310 nonzero weights=26 stop=0.00004
# iter=12500 current objective=226844.310 nonzero weights=26 stop=0.00002
# iter=12600 current objective=226844.310 nonzero weights=26 stop=0.00003
# iter=12700 current objective=226844.310 nonzero weights=26 stop=0.00001
# iter=12800 current objective=226844.310 nonzero weights=26 stop=0.00003
# iter=12900 current objective=226844.310 nonzero weights=26 stop=0.00001
# iter=13000 current objective=226844.310 nonzero weights=26 stop=0.00018
# iter=13100 current objective=226844.309 nonzero weights=26 stop=0.00001
# iter=13200 current objective=226844.309 nonzero weights=26 stop=0.00002
# iter=13300 current objective=226844.309 nonzero weights=26 stop=0.00002
# iter=13400 current objective=226844.309 nonzero weights=26 stop=0.00001
# iter=13500 current objective=226844.309 nonzero weights=26 stop=0.00010
# iter=13600 current objective=226844.309 nonzero weights=26 stop=0.00003
# iter=13700 current objective=226844.309 nonzero weights=26 stop=0.00008
# iter=13800 current objective=226844.309 nonzero weights=26 stop=0.00001
# iter=13900 current objective=226844.309 nonzero weights=26 stop=0.00001
# iter=14000 current objective=226844.309 nonzero weights=26 stop=0.00001
# iter=14100 current objective=226844.309 nonzero weights=26 stop=0.00001
#
# Best lambda via cross-validation: lmbda = 97
#
# Test loss = 184984.77539
